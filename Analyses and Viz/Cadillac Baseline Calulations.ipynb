# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
unfiltered_df = pd.read_csv("Data Analysis 2.28/405781_Cadillac_Baseline_pt_2_zone_trip_all.csv")

# %%
unfiltered_df.columns
# Out:
# Index(['Mode of Travel', 'Intersection Type', 'Zone ID', 'Zone Name',
#        'Zone Is Pass-Through', 'Zone Direction (degrees)',
#        'Zone is Bi-Direction', 'Day Type', 'Day Part',
#        'Average Daily Zone Traffic (StL Volume)', 'Avg Travel Time (sec)',
#        'Avg All Travel Time (sec)', 'Avg Trip Length (mi)',
#        'Avg All Trip Length (mi)', 'Avg Trip Speed (mph)',
#        'Avg All Trip Speed (mph)', 'Avg All Trip Circuity',
#        'Travel Time 0-10 min (percent)', 'Travel Time 10-20 min (percent)',
#        'Travel Time 20-30 min (percent)', 'Travel Time 30-40 min (percent)',
#        'Travel Time 40-50 min (percent)', 'Travel Time 50-60 min (percent)',
#        'Travel Time 60-70 min (percent)', 'Travel Time 70-80 min (percent)',
#        'Travel Time 80-90 min (percent)', 'Travel Time 90-100 min (percent)',
#        'Travel Time 100-110 min (percent)',
#        'Travel Time 110-120 min (percent)',
#        'Travel Time 120-130 min (percent)',
# ...

# %%
unfiltered_df["Zone Name"].unique()
# Out:
# array(['Bottom of Mountain', 'Top of the Mountain'], dtype=object)

# %%
bottom_df = unfiltered_df.loc[np.where(unfiltered_df["Zone Name"] == "Bottom of Mountain")[0], :]
bottom_df = bottom_df.reset_index(drop=True)
top_df = unfiltered_df.loc[np.where(unfiltered_df["Zone Name"] == "Top of the Mountain")[0], :]
top_df = top_df.reset_index(drop=True)

# %%
bottom_df["Day Type"].unique()
# Out:
# array(['0: All Days (M-Su)', '1: Monday (M-M)', '2: Tuesday (Tu-Tu)',
#        '3: Wednesday (W-W)', '4: Thursday (Th-Th)', '5: Friday (F-F)',
#        '6: Saturday (Sa-Sa)', '7: Sunday (Su-Su)'], dtype=object)

# %%
bottom_df["Day Part"].unique()
# Out:
# array(['00: All Day (12am-12am)', '02: 1am (1am-2am)',
#        '03: 2am (2am-3am)', '04: 3am (3am-4am)', '05: 4am (4am-5am)',
#        '06: 5am (5am-6am)', '07: 6am (6am-7am)', '08: 7am (7am-8am)',
#        '09: 8am (8am-9am)', '10: 9am (9am-10am)', '11: 10am (10am-11am)',
#        '12: 11am (11am-12noon)', '13: 12pm (12noon-1pm)',
#        '14: 1pm (1pm-2pm)', '15: 2pm (2pm-3pm)', '16: 3pm (3pm-4pm)',
#        '17: 4pm (4pm-5pm)', '18: 5pm (5pm-6pm)', '19: 6pm (6pm-7pm)',
#        '20: 7pm (7pm-8pm)', '21: 8pm (8pm-9pm)', '22: 9pm (9pm-10pm)',
#        '23: 10pm (10pm-11pm)', '24: 11pm (11pm-12am)'], dtype=object)

# %% [markdown]
# ## Average Traffic

# %%
avg_daily_bottom = bottom_df.loc[np.where(bottom_df["Day Part"] == "00: All Day (12am-12am)")[0],:]
avg_daily_top = top_df.loc[np.where(top_df["Day Part"] == "00: All Day (12am-12am)")[0],:]

# %%
avg_daily_top
# Out:
#                              Mode of Travel  Intersection Type  Zone ID  \
# 0    All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 23   All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 45   All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 65   All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 85   All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 107  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 128  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 150  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
#
#                Zone Name Zone Is Pass-Through  Zone Direction (degrees)  \
# 0    Top of the Mountain                  yes                        30
# 23   Top of the Mountain                  yes                        30
# 45   Top of the Mountain                  yes                        30
# ...

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)


plt.plot(avg_daily_top["Day Type"][1:],avg_daily_top["Average Daily Zone Traffic (StL Volume)"][1:], color="grey", linestyle= "dashed", linewidth = 3, 
         marker = 'o', markerfacecolor = 'lightgreen', markersize =12, label = "Top of Mountain")
for a,b in zip(avg_daily_top["Day Type"][1:], avg_daily_top["Average Daily Zone Traffic (StL Volume)"][1:]): 
    plt.text(a, b, str(round(b)), weight="bold")

plt.plot(avg_daily_bottom["Day Type"][1:],avg_daily_bottom["Average Daily Zone Traffic (StL Volume)"][1:], color="grey", linestyle= "dashed", linewidth = 3, 
         marker = 'o', markerfacecolor = 'lightblue', markersize =12, label = "Bottom of Mountain")
for a,b in zip(avg_daily_bottom["Day Type"][1:], avg_daily_bottom["Average Daily Zone Traffic (StL Volume)"][1:]): 
    plt.text(a, b, str(round(b)), weight="bold")

    
    
# plt.plot(bottom_daily_avg_volume.index[1:], bottom_daily_avg_volume[1:], color="grey", linestyle= "dashed", linewidth = 3, 
#          marker = 'o', markerfacecolor = 'lightblue', markersize =12, label = "Bottom of Mountain")
# for a,b in zip(bottom_daily_avg_volume.index[1:], bottom_daily_avg_volume[1:]): 
#     plt.text(a, b, str(round(b)), weight="bold")
    
plt.xticks(rotation= -45, ha="left")
plt.title("Average Volume for per Day")
plt.ylabel("Avg. Daily Volume")
plt.legend()

# %%
avg_hourly_bottom = bottom_df.loc[np.where(bottom_df["Day Type"] == "0: All Days (M-Su)")[0],:]
avg_hourly_top = top_df.loc[np.where(top_df["Day Type"] == "0: All Days (M-Su)")[0],:]

# %%
all_time = [i for i in avg_hourly_bottom["Day Part"][1:]]

all_time.append('01: 12am (12am-1am)')

# %%
sorted(all_time)
# Out:
# ['01: 12am (12am-1am)',
#  '02: 1am (1am-2am)',
#  '03: 2am (2am-3am)',
#  '04: 3am (3am-4am)',
#  '05: 4am (4am-5am)',
#  '06: 5am (5am-6am)',
#  '07: 6am (6am-7am)',
#  '08: 7am (7am-8am)',
#  '09: 8am (8am-9am)',
#  '10: 9am (9am-10am)',
#  '11: 10am (10am-11am)',
#  '12: 11am (11am-12noon)',
#  '13: 12pm (12noon-1pm)',
#  '14: 1pm (1pm-2pm)',
#  '15: 2pm (2pm-3pm)',
#  '16: 3pm (3pm-4pm)',
#  '17: 4pm (4pm-5pm)',
#  '18: 5pm (5pm-6pm)',
#  '19: 6pm (6pm-7pm)',
#  '20: 7pm (7pm-8pm)',
#  '21: 8pm (8pm-9pm)',
#  '22: 9pm (9pm-10pm)',
#  '23: 10pm (10pm-11pm)',
#  '24: 11pm (11pm-12am)']

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)


plt.plot(sorted(all_time), [0 for i in all_time], color = "white")

plt.plot(avg_hourly_bottom["Day Part"][1:],avg_hourly_bottom["Average Daily Zone Traffic (StL Volume)"][1:], color="grey", linestyle= "dashed", linewidth = 3, 
         marker = 'o', markerfacecolor = 'lightblue', markersize =12, label = "Bottom of Mountain")
for a,b in zip(avg_hourly_bottom["Day Part"][1:], avg_hourly_bottom["Average Daily Zone Traffic (StL Volume)"][1:]): 
    plt.text(a, b, str(round(b)), weight="bold")


plt.plot(avg_hourly_top["Day Part"][1:],avg_hourly_top["Average Daily Zone Traffic (StL Volume)"][1:], color="grey", linestyle= "dashed", linewidth = 3, 
         marker = 'o', markerfacecolor = 'lightgreen', markersize =12, label = "Top of Mountain")
for a,b in zip(avg_hourly_top["Day Part"][1:], avg_hourly_top["Average Daily Zone Traffic (StL Volume)"][1:]): 
    plt.text(a, b, str(round(b)), weight="bold")

    
plt.xticks(rotation= -45, ha="left")
plt.title("Average Volume for per Hour")
plt.ylabel("Avg. Hourly Volume")
plt.legend()

# %%
top_df_pivot = top_df.pivot_table(index='Day Part', columns='Day Type', values= "Average Daily Zone Traffic (StL Volume)")
bottom_df_pivot = bottom_df.pivot_table(index='Day Part', columns='Day Type', values= "Average Daily Zone Traffic (StL Volume)")

# %%
# top_df_pivot = top_df_pivot.fillna(0)
# bottom_df_pivot = bottom_df_pivot.fillna(0)

# %%
top_df_pivot.columns
# Out:
# Index(['0: All Days (M-Su)', '1: Monday (M-M)', '2: Tuesday (Tu-Tu)',
#        '3: Wednesday (W-W)', '4: Thursday (Th-Th)', '5: Friday (F-F)',
#        '6: Saturday (Sa-Sa)', '7: Sunday (Su-Su)'],
#       dtype='object', name='Day Type')

# %%
#Weekday plot
fig, (ax1, ax2) = plt.subplots(2,1)
fig.set_figwidth(15)
fig.set_figheight(14)


ax1.plot(top_df_pivot['0: All Days (M-Su)'].index[1:], top_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
ax1.plot(top_df_pivot['1: Monday (M-M)'].index[1:], top_df_pivot['1: Monday (M-M)'][1:], label = "Monday", linestyle = 'dashed',
        color = 'blue', markerfacecolor = 'blue', marker = 'o')
ax1.plot(top_df_pivot['2: Tuesday (Tu-Tu)'].index[1:], top_df_pivot['2: Tuesday (Tu-Tu)'][1:], label = "Tuesday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')


ax1.plot(sorted(all_time), [0 for i in all_time], color = "white")


ax2.plot(bottom_df_pivot['0: All Days (M-Su)'].index[1:], bottom_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
ax2.plot(bottom_df_pivot['1: Monday (M-M)'].index[1:], bottom_df_pivot['1: Monday (M-M)'][1:], label = "Monday", linestyle = 'dashed',
        color = 'blue', markerfacecolor = 'blue', marker = 'o')
ax2.plot(bottom_df_pivot['2: Tuesday (Tu-Tu)'].index[1:], bottom_df_pivot['2: Tuesday (Tu-Tu)'][1:], label = "Tuesday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')


ax2.plot(sorted(all_time), [0 for i in all_time], color = "white")


ax1.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
ax1.legend()
ax1.set_title("Hourly Volume: Top of the Mountain")


ax2.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
ax2.legend()
ax2.set_title("Hourly Volume: Bottom of the Mountain")
# Out:
# C:\Users\lemcm\AppData\Local\Temp/ipykernel_17904/156114728.py:27: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
# C:\Users\lemcm\AppData\Local\Temp/ipykernel_17904/156114728.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
# Text(0.5, 1.0, 'Hourly Volume: Bottom of the Mountain')

# %%
# #Weekday plot

# f = plt.figure()
# f.set_figwidth(15)
# f.set_figheight(7)



# plt.plot(df_pivot['0: All Days (M-Su)'].index[1:], df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "grey")
# plt.plot(df_pivot['3: Wednesday (W-W)'].index[1:], df_pivot['3: Wednesday (W-W)'][1:], label = "Wednesday", linestyle = 'dashed',
#         color = 'green', markerfacecolor = 'green', marker = 'o')
# plt.plot(df_pivot['4: Thursday (Th-Th)'].index[1:], df_pivot['4: Thursday (Th-Th)'][1:], label = "Thursday", linestyle = 'dashed',
#         color = 'orange', markerfacecolor = 'orange', marker = 'o')


# plt.xticks(rotation= -45, ha="left")
# plt.title("Average Hourly Traffic Per Weekday (Wednesday and Thursday)")
# plt.legend()
# plt.ylim([0, 150])
# plt.show


#Weekday plot
fig, (ax1, ax2) = plt.subplots(2,1)
fig.set_figwidth(15)
fig.set_figheight(14)


ax1.plot(top_df_pivot['0: All Days (M-Su)'].index[1:], top_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
ax1.plot(top_df_pivot['3: Wednesday (W-W)'].index[1:], top_df_pivot['3: Wednesday (W-W)'][1:], label = "Wednesday", linestyle = 'dashed',
        color = 'blue', markerfacecolor = 'blue', marker = 'o')
ax1.plot(top_df_pivot['4: Thursday (Th-Th)'].index[1:], top_df_pivot['4: Thursday (Th-Th)'][1:], label = "Thursday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')


ax1.plot(sorted(all_time), [0 for i in all_time], color = "white")


ax2.plot(bottom_df_pivot['0: All Days (M-Su)'].index[1:], bottom_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
ax2.plot(bottom_df_pivot['3: Wednesday (W-W)'].index[1:], bottom_df_pivot['3: Wednesday (W-W)'][1:], label = "Wednesday", linestyle = 'dashed',
        color = 'blue', markerfacecolor = 'blue', marker = 'o')
ax2.plot(bottom_df_pivot['4: Thursday (Th-Th)'].index[1:], bottom_df_pivot['4: Thursday (Th-Th)'][1:], label = "Thursday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')


ax2.plot(sorted(all_time), [0 for i in all_time], color = "white")


ax1.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
ax1.legend()
ax1.set_title("Hourly Volume: Top of the Mountain")


ax2.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
ax2.legend()
ax2.set_title("Hourly Volume: Bottom of the Mountain")
# Out:
# C:\Users\lemcm\AppData\Local\Temp/ipykernel_17904/1490479568.py:49: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
# C:\Users\lemcm\AppData\Local\Temp/ipykernel_17904/1490479568.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
# Text(0.5, 1.0, 'Hourly Volume: Bottom of the Mountain')

# %%
time_labels_top = [i.split(": ")[1].split(" ")[0] for i in top_df_pivot['0: All Days (M-Su)'].index[1:]]
time_labels_bottom = [i.split(": ")[1].split(" ")[0] for i in bottom_df_pivot['0: All Days (M-Su)'].index[1:]]

# %%
time_labels_bottom
# Out:
# ['6am', '9am', '11am', '12pm', '2pm', '3pm', '5pm', '6pm', '7pm', '8pm']

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
fig.set_figwidth(15)
fig.set_figheight(14)


ax1.plot(top_df_pivot['0: All Days (M-Su)'].index[1:], top_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
ax1.plot(top_df_pivot['5: Friday (F-F)'].index[1:], top_df_pivot['5: Friday (F-F)'][1:], label = "Friday", linestyle= "dashed", color = 'blue',
        marker = 'o', markerfacecolor = 'blue')
ax1.plot(top_df_pivot['6: Saturday (Sa-Sa)'].index[1:], top_df_pivot['6: Saturday (Sa-Sa)'][1:], label = "Saturday", linestyle = 'dashed',
        color = 'orange', markerfacecolor = 'orange', marker = 'o')
ax1.plot(top_df_pivot['7: Sunday (Su-Su)'].index[1:], top_df_pivot['7: Sunday (Su-Su)'][1:], label = "Sunday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')


ax2.plot(bottom_df_pivot['0: All Days (M-Su)'].index[1:], bottom_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
ax2.plot(bottom_df_pivot['5: Friday (F-F)'].index[1:], bottom_df_pivot['5: Friday (F-F)'][1:], label = "Friday", linestyle= "dashed", color = 'blue',
        marker = 'o', markerfacecolor = 'blue')
ax2.plot(bottom_df_pivot['6: Saturday (Sa-Sa)'].index[1:], bottom_df_pivot['6: Saturday (Sa-Sa)'][1:], label = "Saturday", linestyle = 'dashed',
        color = 'orange', markerfacecolor = 'orange', marker = 'o')
ax2.plot(bottom_df_pivot['7: Sunday (Su-Su)'].index[1:], bottom_df_pivot['7: Sunday (Su-Su)'][1:], label = "Sunday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')




ax1.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
ax1.legend()
ax1.set_title("Hourly Volume: Top of the Mountain")


ax2.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
ax2.legend()
ax2.set_title("Hourly Volume: Bottom of the Mountain")
# Out:
# C:\Users\lemcm\AppData\Local\Temp/ipykernel_17904/2622677951.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
# C:\Users\lemcm\AppData\Local\Temp/ipykernel_17904/2622677951.py:31: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels([ i.split(" ")[1] for i in sorted(all_time)], rotation= -45)
# Text(0.5, 1.0, 'Hourly Volume: Bottom of the Mountain')

# %%
#Weekdend plot

f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)


plt.plot(top_df_pivot['0: All Days (M-Su)'].index[1:], top_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
plt.plot(top_df_pivot['5: Friday (F-F)'].index[1:], top_df_pivot['5: Friday (F-F)'][1:], label = "Friday", linestyle= "dashed", color = 'blue',
        marker = 'o', markerfacecolor = 'blue')
plt.plot(top_df_pivot['6: Saturday (Sa-Sa)'].index[1:], top_df_pivot['6: Saturday (Sa-Sa)'][1:], label = "Saturday", linestyle = 'dashed',
        color = 'orange', markerfacecolor = 'orange', marker = 'o')
plt.plot(top_df_pivot['7: Sunday (Su-Su)'].index[1:], top_df_pivot['7: Sunday (Su-Su)'][1:], label = "Sunday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')


plt.xticks(rotation= -45, ha="left")
plt.legend()
plt.ylim([0, 150])
plt.title("Hourly Traffic Per Weekend Day")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Weekdend plot

f = plt.figure()
f.set_figwidth(15)
f.set_figheight(7)


plt.plot(bottom_df_pivot['0: All Days (M-Su)'].index[1:], bottom_df_pivot['0: All Days (M-Su)'][1:], label = "All Days", color = "black")
plt.plot(bottom_df_pivot['5: Friday (F-F)'].index[1:], bottom_df_pivot['5: Friday (F-F)'][1:], label = "Friday", linestyle= "dashed", color = 'blue',
        marker = 'o', markerfacecolor = 'blue')
plt.plot(bottom_df_pivot['6: Saturday (Sa-Sa)'].index[1:], bottom_df_pivot['6: Saturday (Sa-Sa)'][1:], label = "Saturday", linestyle = 'dashed',
        color = 'orange', markerfacecolor = 'orange', marker = 'o')
plt.plot(bottom_df_pivot['7: Sunday (Su-Su)'].index[1:], bottom_df_pivot['7: Sunday (Su-Su)'][1:], label = "Sunday", linestyle = 'dashed',
        color = 'green', markerfacecolor = 'green', marker = 'o')


plt.xticks(rotation= -45, ha="left")
plt.legend()
plt.ylim([0, 150])
plt.title("Hourly Traffic Per Weekend Day")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
