# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Just_Parking_Trip_Info.csv")

# %%
df
# Out:
#                              Mode of Travel  Intersection Type  Zone ID  \
# 0    All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 1    All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 2    All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 3    All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 4    All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# ..                                      ...                ...      ...
# 588  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 589  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 590  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 591  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
# 592  All Vehicles - StL All Vehicles Volume  Trip Pass-Through      NaN
#
#             Zone Name Zone Is Pass-Through  Zone Direction (degrees)  \
# ...
